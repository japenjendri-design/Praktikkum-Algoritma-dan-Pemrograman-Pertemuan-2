# %%
#latihan 2.1

print("==== KALKULATOR TARGET BERAT BADAN ====")

tinggi = float(input("Masukan tinggi badan (m): "))
bmi = float(input("Masukan nilai BMI: "))
berat = bmi * (tinggi ** 2)
print("Berat badan yang diperlukan adalah:", round(berat, 2), "kg")
# Out:
# ==== KALKULATOR TARGET BERAT BADAN ====
# Masukan tinggi badan (m):  175
# Masukan nilai BMI:  78
# Berat badan yang diperlukan adalah: 2388750.0 kg

# %%
#Latihan 2.2

x = int(input("Masukan nilai x (bilangan bulat,tidak boleh 0): "))
if x == 0:
    print("Error: x tidak boleh 0")
else:
    hasil = 2 * (x ** 3) + 2 * x + 15/x

print("Nilai f(x) adalah:", hasil)
# Out:
# Masukan nilai x (bilangan bulat,tidak boleh 0):  100
# Nilai f(x) adalah: 2000200.15

# %%
#latihan 2.3

gaji_perjam = float(input("Masukan gaji perjam"))
jam_perminggu = float(input("Masukan jumlah jam kerja perminggu"))
total_jam = jam_perminggu * 5
gaji_kotor = gaji_perjam * total_jam
pajak = 0.14 * gaji_kotor
pendapatan_bersih = gaji_kotor - pajak
baju = 0.10 * pendapatan_bersih
alat_tulis = 0.01 * pendapatan_bersih
sisa = pendapatan_bersih - baju - alat_tulis
sedekah = 0.25 * sisa
anak_yatim = 0.30 * sedekah
kaum_dhuafa = .70 * sedekah

print("\n=== HASIL PERHITUNGAN===")
print("1. Pendapatan sebelum pajak: Rp", gaji_kotor)
print("2. pendapatan setelah pajak: Rp", pendapatan_bersih)
print("3. Baju & aksesoris: Rp", baju)
print("4. Alat tusil: Rp", alat_tulis)
print("5. Jumlah sedekah: Rp", sedekah)
print("6. Untuk anak yatim: Rp", anak_yatim)
print("7. Untuk dhuafa: Rp", kaum_dhuafa)
# Out:
# Masukan gaji perjam 500_000
# Masukan jumlah jam kerja perminggu 24
# === HASIL PERHITUNGAN===
# 1. Pendapatan sebelum pajak: Rp 60000000.0
# 2. pendapatan setelah pajak: Rp 51600000.0
# 3. Baju & aksesoris: Rp 5160000.0
# 4. Alat tusil: Rp 516000.0
# 5. Jumlah sedekah: Rp 11481000.0
# 6. Untuk anak yatim: Rp 3444300.0
# 7. Untuk dhuafa: Rp 8036699.999999999
